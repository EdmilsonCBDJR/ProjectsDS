# %% [markdown]
# # Módulo 10 tarefa 03
# Considere a mesma base de dados utilizada na tarefa 1 ```previsao_de_renda.csv```.

# %% [markdown]
# 1) Construa um gráfico de barras para avaliar a distribuição das variáveis qualitativas no tempo. Você acha que houve alguma alteração importante a ser investigada?

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# Fixing random state for reproducibility
np.random.seed(2360873)

# %%
prev_renda = pd.read_csv('previsao_de_renda.csv')

prev_renda.head()
# Out:
#    Unnamed: 0    data_ref  index sexo  posse_de_veiculo  posse_de_imovel  \
# 0           0  2015-01-01   8682    F             False             True
# 1           1  2015-01-01  12830    M              True             True
# 2           2  2015-01-01   2885    M              True             True
# 3           3  2015-01-01  16168    F              True            False
# 4           4  2015-01-01  12438    M             False            False
#
#    qtd_filhos   tipo_renda           educacao estado_civil tipo_residencia  \
# 0           1  Assalariado         Secundário       Casado            Casa
# 1           0   Empresário         Secundário       Casado            Casa
# 2           2  Assalariado  Superior completo       Casado            Casa
# 3           0   Empresário         Secundário       Casado            Casa
# 4           0  Assalariado         Secundário       Casado            Casa
#
#    idade  tempo_emprego  qt_pessoas_residencia    mau    renda
# ...

# %%
base1 = prev_renda[['data_ref','posse_de_imovel','posse_de_veiculo','tipo_renda','educacao','estado_civil','tipo_residencia','renda']]

base1.head()
# Out:
#      data_ref  posse_de_imovel  posse_de_veiculo   tipo_renda  \
# 0  2015-01-01             True             False  Assalariado
# 1  2015-01-01             True              True   Empresário
# 2  2015-01-01             True              True  Assalariado
# 3  2015-01-01            False              True   Empresário
# 4  2015-01-01            False             False  Assalariado
#
#             educacao estado_civil tipo_residencia    renda
# 0         Secundário       Casado            Casa  3369.24
# 1         Secundário       Casado            Casa  6096.14
# 2  Superior completo       Casado            Casa  5658.98
# 3         Secundário       Casado            Casa  7246.69
# 4         Secundário       Casado            Casa  4017.37

# %%
#Avaliando as mudanças na linha do tempo para as variáveis
ax = sns.countplot(x='data_ref',  hue = 'tipo_renda', data=base1)

#tick_labs = base1['data_ref'].map(lambda ts: ts.strftime("%m-%Y")).unique()

# tick_labs.tolist()

ticks = ax.set_xticks(list(range(base1['data_ref'].nunique())))
#labels = ax.set_xticklabels(tick_labs, rotation=45)

ax.set_xticklabels(ax.get_xticklabels(), rotation=90, horizontalalignment='right')
# Out:
# [Text(0, 0, '2015-01-01'),
#  Text(1, 0, '2015-02-01'),
#  Text(2, 0, '2015-03-01'),
#  Text(3, 0, '2015-04-01'),
#  Text(4, 0, '2015-05-01'),
#  Text(5, 0, '2015-06-01'),
#  Text(6, 0, '2015-07-01'),
#  Text(7, 0, '2015-08-01'),
#  Text(8, 0, '2015-09-01'),
#  Text(9, 0, '2015-10-01'),
#  Text(10, 0, '2015-11-01'),
#  Text(11, 0, '2015-12-01'),
#  Text(12, 0, '2016-01-01'),
#  Text(13, 0, '2016-02-01'),
#  Text(14, 0, '2016-03-01')]

# %%
#Avaliando as mudanças na linha do tempo para as variáveis
ax = sns.countplot(x='data_ref',  hue = 'estado_civil', data=base1)

#tick_labs = base1['data_ref'].map(lambda ts: ts.strftime("%m-%Y")).unique()

# tick_labs.tolist()

ticks = ax.set_xticks(list(range(base1['data_ref'].nunique())))
#labels = ax.set_xticklabels(tick_labs, rotation=45)

ax.set_xticklabels(ax.get_xticklabels(), rotation=90, horizontalalignment='right')
# Out:
# [Text(0, 0, '2015-01-01'),
#  Text(1, 0, '2015-02-01'),
#  Text(2, 0, '2015-03-01'),
#  Text(3, 0, '2015-04-01'),
#  Text(4, 0, '2015-05-01'),
#  Text(5, 0, '2015-06-01'),
#  Text(6, 0, '2015-07-01'),
#  Text(7, 0, '2015-08-01'),
#  Text(8, 0, '2015-09-01'),
#  Text(9, 0, '2015-10-01'),
#  Text(10, 0, '2015-11-01'),
#  Text(11, 0, '2015-12-01'),
#  Text(12, 0, '2016-01-01'),
#  Text(13, 0, '2016-02-01'),
#  Text(14, 0, '2016-03-01')]

# %%
#Avaliando as mudanças na linha do tempo para as variáveis
ax = sns.countplot(x='data_ref',  hue = 'educacao', data=base1)

#tick_labs = base1['data_ref'].map(lambda ts: ts.strftime("%m-%Y")).unique()

# tick_labs.tolist()

ticks = ax.set_xticks(list(range(base1['data_ref'].nunique())))
#labels = ax.set_xticklabels(tick_labs, rotation=45)

ax.set_xticklabels(ax.get_xticklabels(), rotation=90, horizontalalignment='right')
# Out:
# [Text(0, 0, '2015-01-01'),
#  Text(1, 0, '2015-02-01'),
#  Text(2, 0, '2015-03-01'),
#  Text(3, 0, '2015-04-01'),
#  Text(4, 0, '2015-05-01'),
#  Text(5, 0, '2015-06-01'),
#  Text(6, 0, '2015-07-01'),
#  Text(7, 0, '2015-08-01'),
#  Text(8, 0, '2015-09-01'),
#  Text(9, 0, '2015-10-01'),
#  Text(10, 0, '2015-11-01'),
#  Text(11, 0, '2015-12-01'),
#  Text(12, 0, '2016-01-01'),
#  Text(13, 0, '2016-02-01'),
#  Text(14, 0, '2016-03-01')]

# %%
#Avaliando as mudanças na linha do tempo para as variáveis
ax = sns.countplot(x='data_ref',  hue = 'tipo_residencia', data=base1)

#tick_labs = base1['data_ref'].map(lambda ts: ts.strftime("%m-%Y")).unique()

# tick_labs.tolist()

ticks = ax.set_xticks(list(range(base1['data_ref'].nunique())))
#labels = ax.set_xticklabels(tick_labs, rotation=45)

ax.set_xticklabels(ax.get_xticklabels(), rotation=90, horizontalalignment='right')
# Out:
# [Text(0, 0, '2015-01-01'),
#  Text(1, 0, '2015-02-01'),
#  Text(2, 0, '2015-03-01'),
#  Text(3, 0, '2015-04-01'),
#  Text(4, 0, '2015-05-01'),
#  Text(5, 0, '2015-06-01'),
#  Text(6, 0, '2015-07-01'),
#  Text(7, 0, '2015-08-01'),
#  Text(8, 0, '2015-09-01'),
#  Text(9, 0, '2015-10-01'),
#  Text(10, 0, '2015-11-01'),
#  Text(11, 0, '2015-12-01'),
#  Text(12, 0, '2016-01-01'),
#  Text(13, 0, '2016-02-01'),
#  Text(14, 0, '2016-03-01')]

# %% [markdown]
# 2) Para cada variável qualitativa, construa um gráfico mostrando as médias de cada nível da variável no tempo e avalie a estabilidade. Houve alguma alteração importante? Você acha que se pode utilizar essas variáveis em uma modelagem?

# %%
#testando as variáveis posse_de_imovel	posse_de_veiculo	tipo_renda	educacao	estado_civil	tipo_residencia
ax = sns.pointplot(x="data_ref", y="renda", hue = 'educacao',
                   data=base1, dodge=True, errorbar=('ci', 95))

plt.legend(loc = 'lower center', bbox_to_anchor=(0.5, -.30),ncol = 3)

ax.set_xticklabels(ax.get_xticklabels(), rotation=45, horizontalalignment='right')
# Out:
# [Text(0, 0, '2015-01-01'),
#  Text(1, 0, '2015-02-01'),
#  Text(2, 0, '2015-03-01'),
#  Text(3, 0, '2015-04-01'),
#  Text(4, 0, '2015-05-01'),
#  Text(5, 0, '2015-06-01'),
#  Text(6, 0, '2015-07-01'),
#  Text(7, 0, '2015-08-01'),
#  Text(8, 0, '2015-09-01'),
#  Text(9, 0, '2015-10-01'),
#  Text(10, 0, '2015-11-01'),
#  Text(11, 0, '2015-12-01'),
#  Text(12, 0, '2016-01-01'),
#  Text(13, 0, '2016-02-01'),
#  Text(14, 0, '2016-03-01')]

# %% [markdown]
# ## A escolaridade demonstra uma instabilidade incomum em alguns meses para uma das categorias, eu descartaria a mesma do modelo

# %%
#testando as variáveis posse_de_imovel	posse_de_veiculo	tipo_renda	educacao	estado_civil	tipo_residencia
ax = sns.pointplot(x="data_ref", y="renda", hue = 'tipo_residencia',
                   data=base1, dodge=True, errorbar=('ci', 95))

plt.legend(loc = 'lower center', bbox_to_anchor=(0.5, -.30),ncol = 3)

ax.set_xticklabels(ax.get_xticklabels(), rotation=45, horizontalalignment='right')
# Out:
# [Text(0, 0, '2015-01-01'),
#  Text(1, 0, '2015-02-01'),
#  Text(2, 0, '2015-03-01'),
#  Text(3, 0, '2015-04-01'),
#  Text(4, 0, '2015-05-01'),
#  Text(5, 0, '2015-06-01'),
#  Text(6, 0, '2015-07-01'),
#  Text(7, 0, '2015-08-01'),
#  Text(8, 0, '2015-09-01'),
#  Text(9, 0, '2015-10-01'),
#  Text(10, 0, '2015-11-01'),
#  Text(11, 0, '2015-12-01'),
#  Text(12, 0, '2016-01-01'),
#  Text(13, 0, '2016-02-01'),
#  Text(14, 0, '2016-03-01')]

# %%
#testando as variáveis posse_de_imovel	posse_de_veiculo	tipo_renda	educacao	estado_civil	tipo_residencia
ax = sns.pointplot(x="data_ref", y="renda", hue = 'estado_civil',
                   data=base1, dodge=True, errorbar=('ci', 95))

plt.legend(loc = 'lower center', bbox_to_anchor=(0.5, -.30),ncol = 3)

ax.set_xticklabels(ax.get_xticklabels(), rotation=45, horizontalalignment='right')
# Out:
# [Text(0, 0, '2015-01-01'),
#  Text(1, 0, '2015-02-01'),
#  Text(2, 0, '2015-03-01'),
#  Text(3, 0, '2015-04-01'),
#  Text(4, 0, '2015-05-01'),
#  Text(5, 0, '2015-06-01'),
#  Text(6, 0, '2015-07-01'),
#  Text(7, 0, '2015-08-01'),
#  Text(8, 0, '2015-09-01'),
#  Text(9, 0, '2015-10-01'),
#  Text(10, 0, '2015-11-01'),
#  Text(11, 0, '2015-12-01'),
#  Text(12, 0, '2016-01-01'),
#  Text(13, 0, '2016-02-01'),
#  Text(14, 0, '2016-03-01')]

# %%
#testando as variáveis posse_de_imovel	posse_de_veiculo	tipo_renda	educacao	estado_civil	tipo_residencia
ax = sns.pointplot(x="data_ref", y="renda", hue = 'tipo_renda',
                   data=base1, dodge=True, errorbar=('ci', 95))

plt.legend(loc = 'lower center', bbox_to_anchor=(0.5, -.30),ncol = 3)

ax.set_xticklabels(ax.get_xticklabels(), rotation=45, horizontalalignment='right')
# Out:
# [Text(0, 0, '2015-01-01'),
#  Text(1, 0, '2015-02-01'),
#  Text(2, 0, '2015-03-01'),
#  Text(3, 0, '2015-04-01'),
#  Text(4, 0, '2015-05-01'),
#  Text(5, 0, '2015-06-01'),
#  Text(6, 0, '2015-07-01'),
#  Text(7, 0, '2015-08-01'),
#  Text(8, 0, '2015-09-01'),
#  Text(9, 0, '2015-10-01'),
#  Text(10, 0, '2015-11-01'),
#  Text(11, 0, '2015-12-01'),
#  Text(12, 0, '2016-01-01'),
#  Text(13, 0, '2016-02-01'),
#  Text(14, 0, '2016-03-01')]

# %% [markdown]
# ## Na variável de tipo de renda, o tipo bolsista seria excluído do modelo por ter muitos missings

# %%
#testando as variáveis posse_de_imovel	posse_de_veiculo	tipo_renda	educacao	estado_civil	tipo_residencia
ax = sns.pointplot(x="data_ref", y="renda", hue = 'posse_de_veiculo',
                   data=base1, dodge=True, errorbar=('ci', 95))

plt.legend(loc = 'lower center', bbox_to_anchor=(0.5, -.30),ncol = 3)

ax.set_xticklabels(ax.get_xticklabels(), rotation=45, horizontalalignment='right')
# Out:
# [Text(0, 0, '2015-01-01'),
#  Text(1, 0, '2015-02-01'),
#  Text(2, 0, '2015-03-01'),
#  Text(3, 0, '2015-04-01'),
#  Text(4, 0, '2015-05-01'),
#  Text(5, 0, '2015-06-01'),
#  Text(6, 0, '2015-07-01'),
#  Text(7, 0, '2015-08-01'),
#  Text(8, 0, '2015-09-01'),
#  Text(9, 0, '2015-10-01'),
#  Text(10, 0, '2015-11-01'),
#  Text(11, 0, '2015-12-01'),
#  Text(12, 0, '2016-01-01'),
#  Text(13, 0, '2016-02-01'),
#  Text(14, 0, '2016-03-01')]

# %%
#testando as variáveis posse_de_imovel	posse_de_veiculo	tipo_renda	educacao	estado_civil	tipo_residencia
ax = sns.pointplot(x="data_ref", y="renda", hue = 'posse_de_imovel',
                   data=base1, dodge=True, errorbar=('ci', 95))

plt.legend(loc = 'lower center', bbox_to_anchor=(0.5, -.30),ncol = 3)

ax.set_xticklabels(ax.get_xticklabels(), rotation=45, horizontalalignment='right')
# Out:
# [Text(0, 0, '2015-01-01'),
#  Text(1, 0, '2015-02-01'),
#  Text(2, 0, '2015-03-01'),
#  Text(3, 0, '2015-04-01'),
#  Text(4, 0, '2015-05-01'),
#  Text(5, 0, '2015-06-01'),
#  Text(6, 0, '2015-07-01'),
#  Text(7, 0, '2015-08-01'),
#  Text(8, 0, '2015-09-01'),
#  Text(9, 0, '2015-10-01'),
#  Text(10, 0, '2015-11-01'),
#  Text(11, 0, '2015-12-01'),
#  Text(12, 0, '2016-01-01'),
#  Text(13, 0, '2016-02-01'),
#  Text(14, 0, '2016-03-01')]

# %% [markdown]
# ## Em alguns meses as variáveis invertem a liderança na média salarial, mas no geral, existe predominância de um
